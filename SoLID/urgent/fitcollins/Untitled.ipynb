# %%
import sys, os
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)

# %% [markdown]
# # Load data

# %%
xh = {}

xh['world'] = pd.read_table('h1-world.dat')
xh['solidsyst'] = pd.read_table('h1-solidsyst.dat')
xh['solid'] = pd.read_table('h1-solid.dat')

xh['base0syst'] = pd.read_table('h1-base0syst.dat')
xh['base1syst'] = pd.read_table('h1-base1syst.dat')
xh['base2syst'] = pd.read_table('h1-base2syst.dat')
xh['base3syst'] = pd.read_table('h1-base3syst.dat')

xh['base0'] = pd.read_table('h1-base0.dat')
xh['base1'] = pd.read_table('h1-base1.dat')
xh['base2'] = pd.read_table('h1-base2.dat')
xh['base3'] = pd.read_table('h1-base3.dat')

# %% [markdown]
# # Plot

# %% [markdown]
# ## World vs. SoLID baseline 0

# %%
grid1 = xh['world']
grid2 = xh['base0syst']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-base0syst.pdf")

# %%
grid1 = xh['world']
grid2 = xh['base0']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-base0.pdf")

# %% [markdown]
# ## World vs. SoLID baseline 1

# %%
grid1 = xh['world']
grid2 = xh['base1syst']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-base1syst.pdf")

# %%
grid1 = xh['world']
grid2 = xh['base1']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-base1.pdf")

# %% [markdown]
# ## World vs. SoLID baseline 2

# %%
grid1 = xh['world']
grid2 = xh['base2syst']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-base2syst.pdf")

# %%
grid1 = xh['world']
grid2 = xh['base2']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-base2.pdf")

# %% [markdown]
# ## World vs. SoLID baseline 3

# %%
grid1 = xh['world']
grid2 = xh['base3syst']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-base3syst.pdf")

# %%
grid1 = xh['world']
grid2 = xh['base3']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-base3.pdf")

# %% [markdown]
# ## World vs. SoLID enhanced

# %%
grid1 = xh['world']
grid2 = xh['solidsyst']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-solidsyst.pdf")

# %%
grid1 = xh['world']
grid2 = xh['solid']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
fig.savefig("plots/world-solid.pdf")

# %% [markdown]
# ## Compare baseline and enhanced

# %%
grid1 = xh['base0syst']
grid2 = xh['solidsyst']

nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(grid1['x'], grid1['xu'] - grid1['dxu'] * tol, grid1['xu'] + grid1['dxu'] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(grid1['x'], grid1['xd'] - grid1['dxd'] * tol, grid1['xd'] + grid1['dxd'] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xu'] - grid2['dxu'] * tol, grid2['xu'] + grid2['dxu'] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(grid2['x'], grid2['xd'] - grid2['dxd'] * tol, grid2['xd'] + grid2['dxd'] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(grid1['x'], grid1['xu'], color = 'red', linestyle = '-')
ax.plot(grid1['x'], grid1['xd'], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.45, 0.45)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(grid1['x'], grid1['dxu'] / grid2['dxu'],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(grid1['x'], grid1['dxd'] / grid2['dxd'],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 5)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 1, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 2, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 3, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 4, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
#fig.savefig("plots/base0syst-enhancedsyst.pdf")

# %% [markdown]
# # New heading

# %%
xh = {}

xh['world'] = np.loadtxt('h1-world.dat', skiprows = 1)
xh['solid'] = np.loadtxt('h1-solid.dat', skiprows = 1)
xh['base'] = np.loadtxt('h1-base.dat', skiprows = 1)
xh['others'] = np.loadtxt('h1-others.dat', skiprows = 1)
xh['all'] = np.loadtxt('h1-all.dat', skiprows = 1)

# %%
nrows, ncols = 2, 1
tol = 7.04
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(xh['world'][:,0], xh['world'][:,1] - xh['world'][:,2] * tol, xh['world'][:,1] + xh['world'][:,2] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(xh['world'][:,0], xh['world'][:,3] - xh['world'][:,4] * tol, xh['world'][:,3] + xh['world'][:,4] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(xh['solid'][:,0], xh['solid'][:,1] - xh['solid'][:,2] * tol, xh['solid'][:,1] + xh['solid'][:,2] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(xh['solid'][:,0], xh['solid'][:,3] - xh['solid'][:,4] * tol, xh['solid'][:,3] + xh['solid'][:,4] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(xh['world'][:,0], xh['world'][:,1], color = 'red', linestyle = '-')
ax.plot(xh['world'][:,0], xh['world'][:,3], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.4, 0.4)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm World~vs.~SoLID(full)$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)

ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(xh['world'][:,0], xh['world'][:,2] / xh['solid'][:,2],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(xh['world'][:,0], xh['world'][:,4] / xh['solid'][:,4],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{SoLID}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)

fig.tight_layout()
#fig.savefig("world-full.pdf")

# %%
nrows, ncols = 2, 1
tol = 7.04
#fac = 1.022
fac = 1.0
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(xh['world'][:,0], xh['world'][:,1] - xh['world'][:,2] * tol, xh['world'][:,1] + xh['world'][:,2] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(xh['world'][:,0], xh['world'][:,3] - xh['world'][:,4] * tol, xh['world'][:,3] + xh['world'][:,4] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(xh['base'][:,0], xh['base'][:,1] - xh['base'][:,2] * tol * fac, xh['base'][:,1] + xh['base'][:,2] * tol * fac,\
               color = 'black', alpha = 0.5)
ax.fill_between(xh['base'][:,0], xh['base'][:,3] - xh['base'][:,4] * tol * fac, xh['base'][:,3] + xh['base'][:,4] * tol * fac,\
               color = 'black', alpha = 0.5)
ax.plot(xh['world'][:,0], xh['world'][:,1], color = 'red', linestyle = '-')
ax.plot(xh['world'][:,0], xh['world'][:,3], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.4, 0.4)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm SoLID(Baseline)~vs.~World$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)



ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(xh['world'][:,0], xh['world'][:,2] / xh['base'][:,2] / fac,\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(xh['world'][:,0], xh['world'][:,4] / xh['base'][:,4] / fac,\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 50)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{Baseline}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 30, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 40, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)


fig.tight_layout()
fig.savefig("trans-world-base.pdf")

# %%
nrows, ncols = 2, 1
tol = 7.04
fcl = 1.23
fac = 1.0
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(xh['world'][:,0], xh['world'][:,1] - xh['world'][:,2] * tol, xh['world'][:,1] + xh['world'][:,2] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(xh['world'][:,0], xh['world'][:,3] - xh['world'][:,4] * tol, xh['world'][:,3] + xh['world'][:,4] * tol,\
               color = 'blue', alpha = 0.5)
ax.fill_between(xh['others'][:,0], xh['others'][:,1] - xh['others'][:,2] * tol * fac, xh['others'][:,1] + xh['others'][:,2] * tol * fac,\
               color = 'black', alpha = 0.5)
ax.fill_between(xh['others'][:,0], xh['others'][:,3] - xh['others'][:,4] * tol * fac * fcl, xh['others'][:,3] + xh['others'][:,4] * tol * fac * fcl,\
               color = 'black', alpha = 0.5)
ax.plot(xh['world'][:,0], xh['world'][:,1], color = 'red', linestyle = '-')
ax.plot(xh['world'][:,0], xh['world'][:,3], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.4, 0.4)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm CLAS12+SBS~vs.~World$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)



ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(xh['world'][:,0], xh['world'][:,2] / xh['others'][:,2] / fac,\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(xh['world'][:,0], xh['world'][:,4] / xh['others'][:,4] / fac / fcl,\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 25)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{World}/Error^{CLAS12+SBS}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 5, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 15, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)


fig.tight_layout()
#fig.savefig("trans-world-clas-sbs.pdf")

# %%
nrows, ncols = 2, 1
tol = 7.04
fcl = 1.23
fstat = 0.75
fac = 1.0
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(xh['others'][:,0], xh['others'][:,1] - xh['others'][:,2] * tol, xh['others'][:,1] + xh['others'][:,2] * tol,\
               color = 'red', alpha = 0.5)
ax.fill_between(xh['others'][:,0], xh['others'][:,3] - xh['others'][:,4] * tol * fcl, xh['others'][:,3] + xh['others'][:,4] * tol * fcl,\
               color = 'blue', alpha = 0.5)
ax.fill_between(xh['all'][:,0], xh['all'][:,1] - xh['all'][:,2] * tol * fac, xh['all'][:,1] + xh['all'][:,2] * tol * fac,\
               color = 'black', alpha = 0.5)
ax.fill_between(xh['all'][:,0], xh['all'][:,3] - xh['all'][:,4] * tol * fac * fstat, xh['all'][:,3] + xh['all'][:,4] * tol * fac * fstat,\
               color = 'black', alpha = 0.5)
ax.plot(xh['others'][:,0], xh['others'][:,1], color = 'red', linestyle = '-')
ax.plot(xh['others'][:,0], xh['others'][:,3], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.4, 0.4)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm SoLID(baseline)~vs.~CLAS12+SBS$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)



ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(xh['others'][:,0], xh['others'][:,2] / xh['all'][:,2] / fac,\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(xh['others'][:,0], xh['others'][:,4] * fcl / xh['all'][:,4] / fac / fstat,\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 25)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{CLAS12+SBS}/Error^{SoLID(baseline)}$', size = 25)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 5, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 10, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 15, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 20, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)


fig.tight_layout()
#fig.savefig("trans-solidbase-clas-sbs.pdf")

# %%
nrows, ncols = 2, 1
tol = 7.04
#fac = 1.022
fac = 1.0
fig = plt.figure(figsize = (ncols * 7, nrows * 6))

ax = fig.add_subplot(nrows, ncols, 1)

ax.axhline(y = 0, linestyle = '-', color = 'black', alpha = 0.7)
ax.fill_between(xh['base'][:,0], xh['base'][:,1] - xh['base'][:,2] * tol * fac, xh['base'][:,1] + xh['base'][:,2] * tol * fac,\
               color = 'red', alpha = 0.5)
ax.fill_between(xh['base'][:,0], xh['base'][:,3] - xh['base'][:,4] * tol * fac, xh['base'][:,3] + xh['base'][:,4] * tol * fac,\
               color = 'blue', alpha = 0.5)
ax.fill_between(xh['solid'][:,0], xh['solid'][:,1] - xh['solid'][:,2] * tol, xh['solid'][:,1] + xh['solid'][:,2] * tol,\
               color = 'black', alpha = 0.5)
ax.fill_between(xh['solid'][:,0], xh['solid'][:,3] - xh['solid'][:,4] * tol, xh['solid'][:,3] + xh['solid'][:,4] * tol,\
               color = 'black', alpha = 0.5)
ax.plot(xh['base'][:,0], xh['base'][:,1], color = 'red', linestyle = '-')
ax.plot(xh['base'][:,0], xh['base'][:,3], color = 'blue', linestyle = '-')
ax.set_xlim(0,1)
ax.set_ylim(-0.4, 0.4)
ax.set_ylabel(r'$xh_1(x)$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.set_xticklabels([])
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.text(0.5, 0.95, r'$\rm Enhanced~vs.~Baseline$', transform = ax.transAxes, horizontalalignment = 'center', fontsize = 25)



ax = fig.add_subplot(nrows, ncols, 2)
ax.plot(xh['base'][:,0], xh['base'][:,2] * fac / xh['solid'][:,2],\
        linestyle = '-', linewidth = 5, color = 'red', alpha = 0.5, label = r'$u$')
ax.plot(xh['base'][:,0], xh['base'][:,4] * fac / xh['solid'][:,4],\
        linestyle = '--', linewidth =5, color = 'blue', alpha = 0.5, label = r'$d$')
ax.set_xlim(0,1)
ax.set_ylim(0, 5)
ax.set_xlabel(r'$x$', size = 30)
ax.set_ylabel(r'$\rm Error^{Baseline}/Error^{Enhanced}$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 5, pad = 6, labelsize = 25)
ax.axhline(y = 1, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 2, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 3, linestyle = ':', color = 'black', alpha = 0.5)
ax.axhline(y = 4, linestyle = ':', color = 'black', alpha = 0.5)
ax.axvline(x = 0.05, linestyle = '--', color = 'black', alpha = 0.7)
ax.axvline(x = 0.6, linestyle = '--', color = 'black', alpha = 0.7)
ax.legend(frameon = False, loc = 'upper right', fontsize = 30)


fig.tight_layout()
fig.savefig("trans-base-enhanced.pdf")

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize = (ncols * 7, nrows * 5))
#fac = 1.022
fac = 1.0
ax = fig.add_subplot(nrows, ncols, 1)

ax.errorbar(0.4536, 0, xerr = 0.1026, marker = 'o', color = 'black', markersize = 8, capsize = 6)
ax.errorbar(-0.2254, 0, xerr = 0.2169, marker = 'o', color = 'black', markersize = 8, capsize = 6)
#
#ax.errorbar(0.4536, -1, xerr = 0.0373 * fac, marker = 'o', color = 'green', markersize = 8, capsize = 6)
#ax.errorbar(-0.2254, -1, xerr = 0.0533 * fac, marker = 'o', color = 'green', markersize = 8, capsize = 6)
#
ax.errorbar(0.4536, -1, xerr = 0.0308 * fac, marker = 'o', color = 'blue', markersize = 8, capsize = 6)
ax.errorbar(-0.2254, -1, xerr = 0.0159 * fac, marker = 'o', color = 'blue', markersize = 8, capsize = 6)
#
ax.errorbar(0.4536, -2, xerr = 0.0204, marker = 'o', color = 'red', markersize = 8, capsize = 6)
ax.errorbar(-0.2254, -2, xerr = 0.0107, marker = 'o', color = 'red', markersize = 8, capsize = 6)

ax.set_xlim(-0.5, 1.7)
ax.set_ylim(-2.5, 1.)
ax.set_xlabel(r'$g_T$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', pad =6, labelsize =25)
ax.set_yticks([])

ax.text(0.454, 0.5, r'$u$', fontsize = 25, horizontalalignment = 'center')
ax.text(-0.225, 0.5, r'$d$', fontsize = 25, horizontalalignment = 'center')

ax.text(0.77, 0, r'$\rm World$', fontsize = 25, horizontalalignment = 'left', verticalalignment = 'center')
#ax.text(0.77, -1, r'$\rm CLAS12+SBS$', fontsize = 25, horizontalalignment = 'left', verticalalignment = 'center')
ax.text(0.77, -1, r'$\rm SoLID(Baseline)$', fontsize = 25, horizontalalignment = 'left', verticalalignment = 'center')
ax.text(0.77, -2, r'$\rm SoLID(Enhanced)$', fontsize = 25, horizontalalignment = 'left', verticalalignment = 'center')
ax.text(0.64, 0.72, r'$\rm systematic~uncertainty~included$', fontsize = 17.5, horizontalalignment = 'left', verticalalignment = 'center')

fig.tight_layout()
fig.savefig('gt-world-base-enhanced.pdf')

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize = (ncols * 7, nrows * 5))
#fac = 1.022
fac = 1.0
fstat = 0.75
ax = fig.add_subplot(nrows, ncols, 1)

#ax.errorbar(0.4536, 0, xerr = 0.1026, marker = 'o', color = 'black', markersize = 8, capsize = 6)
#ax.errorbar(-0.2254, 0, xerr = 0.2169, marker = 'o', color = 'black', markersize = 8, capsize = 6)
#
ax.errorbar(0.4536, -0, xerr = 0.0373 * fac, marker = 'o', color = 'green', markersize = 8, capsize = 6)
ax.errorbar(-0.2254, -0, xerr = 0.0533 * fac, marker = 'o', color = 'green', markersize = 8, capsize = 6)
#
ax.errorbar(0.4536, -1, xerr = 0.021 * fac, marker = 'o', color = 'blue', markersize = 8, capsize = 6)
ax.errorbar(-0.2254, -1, xerr = 0.012 * fstat * fac, marker = 'o', color = 'blue', markersize = 8, capsize = 6)
#
ax.errorbar(0.4536, -2, xerr = 0.014, marker = 'o', color = 'red', markersize = 8, capsize = 6)
ax.errorbar(-0.2254, -2, xerr = 0.0083 * fstat, marker = 'o', color = 'red', markersize = 8, capsize = 6)

ax.set_xlim(-0.5, 1.7)
ax.set_ylim(-2.5, 1.)
ax.set_xlabel(r'$g_T$', size = 30)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', pad =6, labelsize =25)
ax.set_yticks([])

ax.text(0.454, 0.5, r'$u$', fontsize = 25, horizontalalignment = 'center')
ax.text(-0.225, 0.5, r'$d$', fontsize = 25, horizontalalignment = 'center')

#ax.text(0.77, 0, r'$\rm World$', fontsize = 25, horizontalalignment = 'left', verticalalignment = 'center')
ax.text(0.77, -0, r'$\rm CLAS12+SBS$', fontsize = 25, horizontalalignment = 'left', verticalalignment = 'center')
ax.text(0.77, -1, r'$\rm SoLID(Baseline)$', fontsize = 25, horizontalalignment = 'left', verticalalignment = 'center')
ax.text(0.77, -2, r'$\rm SoLID(Enhanced)$', fontsize = 25, horizontalalignment = 'left', verticalalignment = 'center')
ax.text(0.67, 0.72, r'$\rm statistical~uncertainty~only$', fontsize = 19, horizontalalignment = 'left', verticalalignment = 'center')

fig.tight_layout()
fig.savefig('gt-classbs-base-enhanced.pdf')
