# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib inline
rc('font', **{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)

# %%
world={}
world['x=0.005'] = pd.read_table('f1t-world-x=0.005.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t', index_col=False)
world['x=0.05'] = pd.read_table('f1t-world-x=0.05.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t', index_col=False)
world['x=0.1'] = pd.read_table('f1t-world-x=0.1.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t', index_col=False)
world['x=0.2'] = pd.read_table('f1t-world-x=0.2.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t', index_col=False)

eic={}
eic['x=0.005'] = pd.read_table('f1t-eic-x=0.005.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t', index_col=False)
eic['x=0.05'] = pd.read_table('f1t-eic-x=0.05.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t', index_col=False)
eic['x=0.1'] = pd.read_table('f1t-eic-x=0.1.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t', index_col=False)
eic['x=0.2'] = pd.read_table('f1t-eic-x=0.2.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t', index_col=False)

pars={}
pars['world'] = pd.read_table('out-world.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t')
pars['eic'] = pd.read_table('out-eic.dat', skiprows = 0, header = 0, engine = 'python', sep = '\t')

# %% [markdown]
# # Plots -- separate

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*7, nrows*7*0.65))

ax = fig.add_subplot(nrows, ncols, 1)
ax.fill_between(world['x=0.005']['kt'], world['x=0.005']['d']-world['x=0.005']['dd'], world['x=0.005']['d']+world['x=0.005']['dd'],\
               color = 'gray', alpha = 0.35)
ax.fill_between(eic['x=0.005']['kt'], eic['x=0.005']['d']-eic['x=0.005']['dd'], eic['x=0.005']['d']+eic['x=0.005']['dd'],\
               color = 'red', alpha = 0.6)
ax.set_xlim(0,1.5)
ax.set_ylim(0,10)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([0,0.5,1,1.5])
ax.set_xticklabels([])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('dslice-x=0.005.pdf', transparent = True)

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*7, nrows*7*0.65))

ax = fig.add_subplot(nrows, ncols, 1)
ax.fill_between(world['x=0.05']['kt'], world['x=0.05']['d']-world['x=0.05']['dd'], world['x=0.05']['d']+world['x=0.05']['dd'],\
               color = 'gray', alpha = 0.35)
ax.fill_between(eic['x=0.05']['kt'], eic['x=0.05']['d']-eic['x=0.05']['dd'], eic['x=0.05']['d']+eic['x=0.05']['dd'],\
               color = 'red', alpha = 0.6)
ax.set_xlim(0,1.5)
ax.set_ylim(0,2)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([0,0.5,1,1.5])
ax.set_xticklabels([])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('dslice-x=0.05.pdf', transparent = True)

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*7, nrows*7*0.65))

ax = fig.add_subplot(nrows, ncols, 1)
ax.fill_between(world['x=0.1']['kt'], world['x=0.1']['d']-world['x=0.1']['dd'], world['x=0.1']['d']+world['x=0.1']['dd'],\
               color = 'gray', alpha = 0.35)
ax.fill_between(eic['x=0.1']['kt'], eic['x=0.1']['d']-eic['x=0.1']['dd'], eic['x=0.1']['d']+eic['x=0.1']['dd'],\
               color = 'red', alpha = 0.6)
ax.set_xlim(0,1.5)
ax.set_ylim(0,2)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([0,0.5,1,1.5])
ax.set_xticklabels([])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('dslice-x=0.1.pdf', transparent = True)

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*7, nrows*7*0.65))

ax = fig.add_subplot(nrows, ncols, 1)
ax.fill_between(world['x=0.2']['kt'], world['x=0.2']['d']-world['x=0.2']['dd'], world['x=0.2']['d']+world['x=0.2']['dd'],\
               color = 'gray', alpha = 0.35)
ax.fill_between(eic['x=0.2']['kt'], eic['x=0.2']['d']-eic['x=0.2']['dd'], eic['x=0.2']['d']+eic['x=0.2']['dd'],\
               color = 'red', alpha = 0.6)
ax.set_xlim(0,1.5)
ax.set_ylim(0,1)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([0,0.5,1,1.5])
ax.set_xticklabels([])
ax.set_yticks([0,0.5,1])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('dslice-x=0.2.pdf', transparent = True)

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*7, nrows*7*0.65))

ax = fig.add_subplot(nrows, ncols, 1)
ax.fill_between(world['x=0.005']['kt'], -world['x=0.005']['u']-world['x=0.005']['du'], -world['x=0.005']['u']+world['x=0.005']['du'],\
               color = 'gray', alpha = 0.35)
ax.fill_between(eic['x=0.005']['kt'], -eic['x=0.005']['u']-eic['x=0.005']['du'], -eic['x=0.005']['u']+eic['x=0.005']['du'],\
               color = 'red', alpha = 0.6)
ax.set_xlim(0,1.5)
ax.set_ylim(0,8)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([0,0.5,1,1.5])
ax.set_xticklabels([])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('uslice-x=0.005.pdf', transparent = True)

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*7, nrows*7*0.65))

ax = fig.add_subplot(nrows, ncols, 1)
ax.fill_between(world['x=0.05']['kt'], -world['x=0.05']['u']-world['x=0.05']['du'], -world['x=0.05']['u']+world['x=0.05']['du'],\
               color = 'gray', alpha = 0.35)
ax.fill_between(eic['x=0.05']['kt'], -eic['x=0.05']['u']-eic['x=0.05']['du'], -eic['x=0.05']['u']+eic['x=0.05']['du'],\
               color = 'red', alpha = 0.6)
ax.set_xlim(0,1.5)
ax.set_ylim(0,2)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([0,0.5,1,1.5])
ax.set_xticklabels([])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('uslice-x=0.05.pdf', transparent = True)

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*7, nrows*7*0.65))

ax = fig.add_subplot(nrows, ncols, 1)
ax.fill_between(world['x=0.1']['kt'], -world['x=0.1']['u']-world['x=0.1']['du'], -world['x=0.1']['u']+world['x=0.1']['du'],\
               color = 'gray', alpha = 0.35)
ax.fill_between(eic['x=0.1']['kt'], -eic['x=0.1']['u']-eic['x=0.1']['du'], -eic['x=0.1']['u']+eic['x=0.1']['du'],\
               color = 'red', alpha = 0.6)
ax.set_xlim(0,1.5)
ax.set_ylim(0,1.5)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([0,0.5,1,1.5])
ax.set_yticks([0,0.5,1,1.5])
ax.set_xticklabels([])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('uslice-x=0.1.pdf', transparent = True)

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*7, nrows*7*0.65))

ax = fig.add_subplot(nrows, ncols, 1)
ax.fill_between(world['x=0.2']['kt'], -world['x=0.2']['u']-world['x=0.2']['du'], -world['x=0.2']['u']+world['x=0.2']['du'],\
               color = 'gray', alpha = 0.35)
ax.fill_between(eic['x=0.2']['kt'], -eic['x=0.2']['u']-eic['x=0.2']['du'], -eic['x=0.2']['u']+eic['x=0.2']['du'],\
               color = 'red', alpha = 0.6)
ax.set_xlim(0,1.5)
ax.set_ylim(0,1)
ax.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([0,0.5,1,1.5])
ax.set_yticks([0,0.5,1])
ax.set_xticklabels([])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('uslice-x=0.2.pdf', transparent = True)

# %% [markdown]
# # Plots -- combine

# %%
nrows, ncols = 1, 1

fig = plt.figure(figsize=(ncols*10, nrows*10))

ax = fig.add_axes([0, 0, 1, 1])
ax.patch.set_alpha(0)
ax.set_axis_off()
ax.arrow(0.05, 0.05, 0, 0.9, linewidth = 1.5, head_width=0.02, head_length = 0.05, fc = 'k', ec = 'k', shape = 'full')
ax.text(0.02, 0.5, r'Down quark Sivers function $\bf f_{1T}^\perp(x,k_T)$', size = 25,\
        horizontalalignment = 'center', verticalalignment = 'center', rotation = 90)
ax.arrow(0.1, 0.1, 0.3, 0.3, linewidth = 1, head_width=0, alpha = 0.5)
ax.arrow(0.1+0.5/3, 0.1, 0.3, 0.3, linewidth = 0.5, head_width=0, alpha = 0.5)
ax.arrow(0.1+1./3, 0.1, 0.3, 0.3, linewidth = 0.5, head_width=0, alpha = 0.5)
ax.arrow(0.1+0.5, 0.1, 0.3, 0.3, linewidth = 0.5, head_width=0, alpha = 0.5)
ax.arrow(0.1, 0.1+0.5*0.65, 0.3, 0.3, linewidth = 0.5, head_width=0, alpha = 0.5)

ax1 = fig.add_axes([0.4, 0.4, 0.5, 0.5*0.65])
ax1.patch.set_alpha(0)
ax1.fill_between(world['x=0.2']['kt'], world['x=0.2']['d']-world['x=0.2']['dd'], world['x=0.2']['d']+world['x=0.2']['dd'],\
               color = 'gray', alpha = 0.35)
ax1.fill_between(eic['x=0.2']['kt'], eic['x=0.2']['d']-eic['x=0.2']['dd'], eic['x=0.2']['d']+eic['x=0.2']['dd'],\
               color = 'red', alpha = 0.6)
ax1.set_xlim(0,1.5)
ax1.set_ylim(0,1)
ax1.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.set_xticks([0,0.5,1,1.5])
ax1.set_xticklabels([])
ax1.set_yticks([0,0.5,1])
ax1.set_yticklabels([])

ax2 = fig.add_axes([0.3, 0.3, 0.5, 0.5*0.65])
ax2.patch.set_alpha(0)
ax2.fill_between(world['x=0.05']['kt'], world['x=0.05']['d']-world['x=0.05']['dd'], world['x=0.05']['d']+world['x=0.05']['dd'],\
               color = 'gray', alpha = 0.35)
ax2.fill_between(eic['x=0.05']['kt'], eic['x=0.05']['d']-eic['x=0.05']['dd'], eic['x=0.05']['d']+eic['x=0.05']['dd'],\
               color = 'red', alpha = 0.6)
ax2.set_xlim(0,1.5)
ax2.set_ylim(0,2)
ax2.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.set_xticks([0,0.5,1,1.5])
ax2.set_xticklabels([])
ax2.set_yticklabels([])


ax4 = fig.add_axes([0.1, 0.1, 0.5, 0.5*0.65])
ax4.patch.set_alpha(0)
ax4.fill_between(world['x=0.005']['kt'], world['x=0.005']['d']-world['x=0.005']['dd'], world['x=0.005']['d']+world['x=0.005']['dd'],\
               color = 'gray', alpha = 0.35)
ax4.fill_between(eic['x=0.005']['kt'], eic['x=0.005']['d']-eic['x=0.005']['dd'], eic['x=0.005']['d']+eic['x=0.005']['dd'],\
               color = 'red', alpha = 0.6)
ax4.set_xlim(0,1.5)
ax4.set_ylim(0,10)
ax4.tick_params(axis = 'both', which = 'both', direction = 'in', length = 6, pad = 6, labelsize = 25)
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.set_xticks([0,0.5,1,1.5])
ax4.set_xticklabels([])
ax4.set_yticklabels([])

#fig.tight_layout()
#fig.savefig('dsivers.pdf', transparent = True)
# Out:
# []

# %%
nrows, ncols = 3, 3

fig = plt.figure(figsize=(ncols*10, nrows*10*0.75))

ax = fig.add_subplot(nrows, ncols, 1)
ax.hist(pars['world']['Nuv'], bins=20, range=(0,0.4), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['Nuv'], bins=20, range=(0,0.4), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'Nuv', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(0,0.4)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_yticklabels([])

ax = fig.add_subplot(nrows, ncols, 2)
ax.hist(pars['world']['auv'], bins=20, range=(0,2), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['auv'], bins=20, range=(0,2), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'auv', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(0,2)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_yticklabels([])

ax = fig.add_subplot(nrows, ncols, 3)
ax.hist(pars['world']['buv'], bins=20, range=(0,20), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['buv'], bins=20, range=(0,20), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'buv', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(0,20)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_yticklabels([])

ax = fig.add_subplot(nrows, ncols, 4)
ax.hist(pars['world']['Ndv'], bins=20, range=(-0.6,-0.2), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['Ndv'], bins=20, range=(-0.6,-0.2), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'Ndv', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(-0.6,-0.2)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_yticklabels([])

ax = fig.add_subplot(nrows, ncols, 5)
ax.hist(pars['world']['adv'], bins=20, range=(0,4), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['adv'], bins=20, range=(0,4), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'adv', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(0,4)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_yticklabels([])

ax = fig.add_subplot(nrows, ncols, 6)
ax.hist(pars['world']['bdv'], bins=20, range=(0,24), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['bdv'], bins=20, range=(0,24), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'bdv', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(0,24)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_yticklabels([])

ax = fig.add_subplot(nrows, ncols, 7)
ax.hist(pars['world']['M1'], bins=20, range=(0,2.5), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['M1'], bins=20, range=(0,2.5), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'M1', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(0,2.5)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_yticklabels([])

ax = fig.add_subplot(nrows, ncols, 8)
ax.hist(pars['world']['Nub'], bins=20, range=(-0.1,0.2), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['Nub'], bins=20, range=(-0.1,0.2), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'Nub', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(-0.1,0.2)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_xticks([-0.1,0,0.1,0.2])
ax.set_yticklabels([])

ax = fig.add_subplot(nrows, ncols, 9)
ax.hist(pars['world']['Ndb'], bins=20, range=(-0.2,0.1), color='gray', alpha=0.5, linewidth=2)
ax.hist(pars['eic']['Ndb'], bins=20, range=(-0.2,0.1), color='red', alpha=0.6, linewidth=2)
ax.text(0.1, 0.9, r'Ndb', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, size=40)
ax.set_xlim(-0.2,0.1)
ax.tick_params(axis='both', which='both', length=8, direction='in', labelsize=30)
ax.set_xticks([-0.2,-0.1,0,0.1])
ax.set_yticklabels([])

fig.tight_layout()
fig.savefig('pardistri.pdf', transparent=True)
